# %%
import pandas as pd
import os

# %%
energyC = pd.read_csv (r'INT-Export-worldEnergyYearly.csv')

# %%
energyC
# Out:
#      Report generated on: 12-29-2022 11:25:43  \
# 0                                         API
# 1                                         NaN
# 2                       INTL.44-1-WORL-QBTU.A
# 3                        INTL.44-1-AFG-QBTU.A
# 4                        INTL.44-1-ALB-QBTU.A
# ...                                       ...
# 1620                   INTL.4418-1-WAK-QBTU.A
# 1621                   INTL.4418-1-ESH-QBTU.A
# 1622                   INTL.4418-1-YEM-QBTU.A
# 1623                   INTL.4418-1-ZMB-QBTU.A
# 1624                   INTL.4418-1-ZWE-QBTU.A
#
#                               Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                                    NaN         1980         1981
# 1     total energy production (quad Btu)          NaN          NaN
# 2                                  World  296.3424356  291.2937659
# 3                            Afghanistan  0.072561156  0.092723655
# 4                                Albania   0.15556162  0.158691383
# ...

# %%
energyC.columns = energyC.iloc[0]

# %%
energyC = energyC.drop(['API'], axis=1)
#The API info is not needed

# %%
energyC.rename(columns={ energyC.columns[0]: 'World'}, inplace = True)

# %%
energyC
# Out:
# 0                                  World         1980         1981  \
# 0                                    NaN         1980         1981
# 1     total energy production (quad Btu)          NaN          NaN
# 2                                  World  296.3424356  291.2937659
# 3                            Afghanistan  0.072561156  0.092723655
# 4                                Albania   0.15556162  0.158691383
# ...                                  ...          ...          ...
# 1620                         Wake Island            0            0
# 1621                      Western Sahara            0            0
# 1622                               Yemen            0            0
# 1623                              Zambia   0.09359591  0.101143253
# 1624                            Zimbabwe  0.041981256  0.043344924
#
# 0            1982         1983         1984         1985         1986  \
# 0            1982         1983         1984         1985         1986
# ...

# %%
energyC = energyC.iloc[2] #We only need the world info for the analysis

# %%
energyC #Dataset #1
# Out:
# 0
# World          World
# 1980     296.3424356
# 1981     291.2937659
# 1982      290.128203
# 1983      293.047718
# 1984     308.9468834
# 1985     316.4925296
# 1986       326.77104
# 1987      334.398773
# 1988     347.4260513
# 1989     354.0364853
# 1990     357.6579078
# 1991     354.9531364
# 1992     353.7276721
# 1993     354.3861018
# 1994     360.4427565
# 1995     368.3400726
# 1996     377.5186505
# 1997     382.0654227
# 1998     386.5962198
# 1999        386.3867
# 2000     399.5432742
# 2001     405.2191265
# 2002     407.0617188
# 2003     422.7334243
# 2004     445.0398125
# 2005     460.9817015
# 2006     473.3646374
# 2007     481.9619898
# 2008     495.3029326
# 2009      492.727998
# 2010     517.8563437
# 2011     533.3323144
# 2012     545.5966162
# 2013     553.7450243
# 2014      563.207886
# 2015     568.3123474
# 2016      564.492523
# 2017     579.0744861
# 2018     600.6668826
# 2019     611.1215834
# 2020     586.0864248
# 2021     606.8165994
# ...

# %%
gdpC = pd.read_csv (r'GDP WorldWide Resaved.csv')

# %%
gdpC.head(25)
# Out:
#                     Data Source World Development Indicators  \
# 0                           NaN                          NaN
# 1             Last Updated Date                   12/22/2022
# 2                           NaN                          NaN
# 3                  Country Name                 Country Code
# 4                         Aruba                          ABW
# 5   Africa Eastern and Southern                          AFE
# 6                   Afghanistan                          AFG
# 7    Africa Western and Central                          AFW
# 8                        Angola                          AGO
# 9                       Albania                          ALB
# 10                      Andorra                          AND
# 11                   Arab World                          ARB
# 12         United Arab Emirates                          ARE
# 13                    Argentina                          ARG
# ...

# %%
gdpC.columns = gdpC.iloc[3].astype(str) #as a string so it can be used with loc function

# %%
gdpC.tail(25) #World is index 263
# Out:
# 3                                 Country Name Country Code  \
# 245  Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 246                        Trinidad and Tobago          TTO
# 247                                    Tunisia          TUN
# 248                                    Turkiye          TUR
# 249                                     Tuvalu          TUV
# 250                                   Tanzania          TZA
# 251                                     Uganda          UGA
# 252                                    Ukraine          UKR
# 253                        Upper middle income          UMC
# 254                                    Uruguay          URY
# 255                              United States          USA
# 256                                 Uzbekistan          UZB
# 257             St. Vincent and the Grenadines          VCT
# 258                              Venezuela, RB          VEN
# 259                     British Virgin Islands          VGB
# ...

# %%
gdpCA = gdpC.iloc[:, [0]]

# %%
gdpCA
# Out:
# 3         Country Name
# 0                  NaN
# 1    Last Updated Date
# 2                  NaN
# 3         Country Name
# 4                Aruba
# ..                 ...
# 265             Kosovo
# 266        Yemen, Rep.
# 267       South Africa
# 268             Zambia
# 269           Zimbabwe
#
# [270 rows x 1 columns]

# %%
gdpCB = gdpC.loc[:, '1980.0':'2021.0'] #This is the year range for the energy dataset

# %%
gdpCB
# Out:
# 3          1980.0        1981.0        1982.0        1983.0        1984.0  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3    1.980000e+03  1.981000e+03  1.982000e+03  1.983000e+03  1.984000e+03
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 265           NaN           NaN           NaN           NaN           NaN
# 266           NaN           NaN           NaN           NaN           NaN
# 267  8.941189e+10  9.314148e+10  8.590407e+10  9.620411e+10  8.487013e+10
# 268  3.829500e+09  3.872667e+09  3.994778e+09  3.216308e+09  2.739444e+09
# 269  6.678868e+09  8.011374e+09  8.539701e+09  7.764067e+09  6.352126e+09
#
# 3          1985.0        1986.0        1987.0        1988.0        1989.0  \
# ...

# %%
gdpC = pd.concat([gdpCA,gdpCB], axis=1)

# %%
gdpC
# Out:
# 3         Country Name        1980.0        1981.0        1982.0  \
# 0                  NaN           NaN           NaN           NaN
# 1    Last Updated Date           NaN           NaN           NaN
# 2                  NaN           NaN           NaN           NaN
# 3         Country Name  1.980000e+03  1.981000e+03  1.982000e+03
# 4                Aruba           NaN           NaN           NaN
# ..                 ...           ...           ...           ...
# 265             Kosovo           NaN           NaN           NaN
# 266        Yemen, Rep.           NaN           NaN           NaN
# 267       South Africa  8.941189e+10  9.314148e+10  8.590407e+10
# 268             Zambia  3.829500e+09  3.872667e+09  3.994778e+09
# 269           Zimbabwe  6.678868e+09  8.011374e+09  8.539701e+09
#
# 3          1983.0        1984.0        1985.0        1986.0        1987.0  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
gdpC =gdpC.loc[263]

# %%
gdpC #Dataset #2
# Out:
# 3
# Country Name               World
# 1980.0          11336600000000.0
# 1981.0          11727600000000.0
# 1982.0          11609800000000.0
# 1983.0          11840100000000.0
# 1984.0          12271600000000.0
# 1985.0          12862200000000.0
# 1986.0          15207800000000.0
# 1987.0          17310300000000.0
# 1988.0          19341200000000.0
# 1989.0          20197500000000.0
# 1990.0          22783800000000.0
# 1991.0          23763600000000.0
# 1992.0          25410300000000.0
# 1993.0          25826300000000.0
# 1994.0          27876800000000.0
# 1995.0          31048500000000.0
# 1996.0          31741900000000.0
# 1997.0          31627800000000.0
# 1998.0          31546600000000.0
# 1999.0          32745500000000.0
# 2000.0          33839600000000.0
# 2001.0          33624000000000.0
# 2002.0          34918000000000.0
# 2003.0          39152300000000.0
# 2004.0          44124000000000.0
# 2005.0          47784400000000.0
# 2006.0          51780200000000.0
# ...

# %%
energyC.to_csv('energyC.csv')
gdpC.to_csv ('gdpC.csv')
